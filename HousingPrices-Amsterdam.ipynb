# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nit = pd.read_csv('/content/HousingPrices-Amsterdam-August-2021.csv')
nit.head(300)
# Out:
#      Unnamed: 0                                         Address      Zip  \
# 0             1                    Blasiusstraat 8 2, Amsterdam  1091 CR
# 1             2          Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL
# 2             3                      Zaaiersweg 11 A, Amsterdam  1097 SM
# 3             4                    Tenerifestraat 40, Amsterdam  1060 TH
# 4             5                      Winterjanpad 21, Amsterdam  1036 KN
# ..          ...                                             ...      ...
# 295         296  Tweede Jan van der Heijdenstraat 13, Amsterdam  1073 VE
# 296         297                 Churchill-laan 216 3, Amsterdam  1078 EW
# 297         298                      Hogevecht 186 B, Amsterdam  1102 HJ
# 298         299             Valkenburgerstraat 138 A, Amsterdam  1011 NA
# 299         300                      Pontsteiger 137, Amsterdam  1014 ZP
#
#          Price  Area  Room       Lon        Lat
# ...

# %%
nit.shape
# Out:
# (924, 8)

# %%
nit.dtypes
# Out:
# Unnamed: 0      int64
# Address        object
# Zip            object
# Price         float64
# Area            int64
# Room            int64
# Lon           float64
# Lat           float64
# dtype: object

# %%
nit.count()
# Out:
# Unnamed: 0    924
# Address       924
# Zip           924
# Price         920
# Area          924
# Room          924
# Lon           924
# Lat           924
# dtype: int64

# %%
nit.describe()
# Out:
#        Unnamed: 0         Price        Area        Room         Lon  \
# count  924.000000  9.200000e+02  924.000000  924.000000  924.000000
# mean   462.500000  6.220654e+05   95.952381    3.571429    4.888605
# std    266.880123  5.389942e+05   57.447436    1.592332    0.053140
# min      1.000000  1.750000e+05   21.000000    1.000000    4.644819
# 25%    231.750000  3.500000e+05   60.750000    3.000000    4.855834
# 50%    462.500000  4.670000e+05   83.000000    3.000000    4.886818
# 75%    693.250000  7.000000e+05  113.000000    4.000000    4.922337
# max    924.000000  5.950000e+06  623.000000   14.000000    5.029122
#
#               Lat
# count  924.000000
# mean    52.363326
# std      0.024028
# min     52.291519
# 25%     52.352077
# 50%     52.364631
# 75%     52.377598
# max     52.423805

# %%
nit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  924 non-null    int64
#  1   Address     924 non-null    object
#  2   Zip         924 non-null    object
#  3   Price       920 non-null    float64
#  4   Area        924 non-null    int64
#  5   Room        924 non-null    int64
#  6   Lon         924 non-null    float64
#  7   Lat         924 non-null    float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 57.9+ KB

# %%
nit.columns
# Out:
# Index(['Unnamed: 0', 'Address', 'Zip', 'Price', 'Area', 'Room', 'Lon', 'Lat'], dtype='object')

# %%
nit.corr()
# Out:
#             Unnamed: 0     Price      Area      Room       Lon       Lat
# Unnamed: 0    1.000000 -0.116311 -0.072850 -0.029082 -0.028796  0.004138
# Price        -0.116311  1.000000  0.835090  0.623448 -0.013561  0.062196
# Area         -0.072850  0.835090  1.000000  0.812421  0.012196  0.017993
# Room         -0.029082  0.623448  0.812421  1.000000 -0.036585 -0.016381
# Lon          -0.028796 -0.013561  0.012196 -0.036585  1.000000 -0.184436
# Lat           0.004138  0.062196  0.017993 -0.016381 -0.184436  1.000000

# %%
nit.isnull().sum()
# Out:
# Unnamed: 0    0
# Address       0
# Zip           0
# Price         4
# Area          0
# Room          0
# Lon           0
# Lat           0
# dtype: int64

# %%
nit.loc[: , :]
# Out:
#      Unnamed: 0                                 Address      Zip     Price  \
# 0             1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0
# 1             2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0
# 2             3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0
# 3             4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0
# 4             5              Winterjanpad 21, Amsterdam  1036 KN  720000.0
# ..          ...                                     ...      ...       ...
# 919         920                     Ringdijk, Amsterdam  1097 AE  750000.0
# 920         921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0
# 921         922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0
# 922         923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0
# 923         924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0
#
#      Area  Room       Lon        Lat
# ...

# %%
print(nit['Address'].unique ())
# Out:
# ['Blasiusstraat 8 2, Amsterdam' 'Kromme Leimuidenstraat 13 H, Amsterdam'
#  'Zaaiersweg 11 A, Amsterdam' 'Tenerifestraat 40, Amsterdam'
#  'Winterjanpad 21, Amsterdam' 'De Wittenkade 134 I, Amsterdam'
#  'Pruimenstraat 18 B, Amsterdam' 'Da Costakade 32 II, Amsterdam'
#  'Postjeskade 41 2, Amsterdam' 'Van Ostadestraat 193 H, Amsterdam'
#  'Sloterkade 152 1, Amsterdam' 'KNSM-laan 609, Amsterdam'
#  'Blasiusstraat 17 II, Amsterdam' 'Amstel 124 B, Amsterdam'
#  'Blasiusstraat 50 II, Amsterdam' 'Suikerpeerpad 39, Amsterdam'
#  'Paramaribostraat 122 3, Amsterdam'
#  'Burgemeester Hogguerstraat 273, Amsterdam'
#  'Anna Blamansingel 274 VII, Amsterdam' 'Oostzaanstraat 271, Amsterdam'
#  'Keizersgracht 171 F, Amsterdam' 'Cornelis Troostplein 2 2, Amsterdam'
#  'Thorn Prikkerstraat 93, Amsterdam' 'Kramatweg 58 A, Amsterdam'
#  'Bramzeilhof 56, Amsterdam' 'Bruinvisstraat 36, Amsterdam'
#  'Arent Janszoon Ernststraat 41, Amsterdam'
# ...

# %%
nit['Lon'].value_counts()
# Out:
# 4.855832    4
# 4.907085    3
# 4.909819    3
# 4.939240    2
# 4.885645    2
#            ..
# 4.787874    1
# 4.802560    1
# 4.956167    1
# 4.923315    1
# 4.810678    1
# Name: Lon, Length: 894, dtype: int64

# %%
nit['Lat'].value_counts() > 30
# Out:
# 52.352385    False
# 52.372907    False
# 52.347558    False
# 52.368653    False
# 52.292324    False
#              ...
# 52.383877    False
# 52.380679    False
# 52.317822    False
# 52.379524    False
# 52.355493    False
# Name: Lat, Length: 886, dtype: bool

# %%
nit['Area'].mean()
# Out:
# 95.95238095238095

# %%
pd.DataFrame(nit['Price'])
# Out:
#         Price
# 0    685000.0
# 1    475000.0
# 2    850000.0
# 3    580000.0
# 4    720000.0
# ..        ...
# 919  750000.0
# 920  350000.0
# 921  350000.0
# 922  599000.0
# 923  300000.0
#
# [924 rows x 1 columns]

# %%
nit['Room'].value_counts().plot.bar()

# %%
sns.violinplot(x= 'Room', y='Price', data= nit, color='r')

# %%
nit['Room'].value_counts().plot.barh(color='y')

# %%
nit['Price'].value_counts().plot.bar(color='r')

# %%
nit['Zip'].value_counts().plot.hist(color='g')

# %%
nit['Area'].value_counts().plot.box(color='hotpink')

# %%
nit['Zip'].value_counts().plot.barh(color='hotpink', width=0.5)

# %%
nit['Lat'].value_counts().plot.barh(color='y', width=0.5)

# %%
fig= px.histogram(nit, x='Lon' , width=900, height=500, template='simple_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(nit, x='Price' , width=900, height=500, template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(nit, x='Zip' , width=900, height=500, template='seaborn')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(nit, x='Area' , width=900, height=500, template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.scatter(nit['Room'] , nit['Area'], color='g')
plt.show()

# %%
plt.scatter(nit['Zip'] , nit['Lat'], color='r')
plt.colorbar()
plt.show()

# %%
nit['Price'].unique()
# Out:
# array([ 685000.,  475000.,  850000.,  580000.,  720000.,  450000.,
#         590000.,  399000.,  300000.,  540000.,  539000.,  390000.,
#         575000.,  650000.,  700000.,  325000.,  375000., 1625000.,
#         600000.,  525000.,  350000., 1650000.,  800000., 1950000.,
#         735000., 3925000.,  275000.,  570000.,  895000.,  365000.,
#         550000.,  429000.,  425000., 1185000.,  385000.,  687500.,
#         585000., 1295000.,  500000.,  400000.,  330000.,  369000.,
#         245000.,      nan,  335000.,  395000.,  415000.,  469000.,
#         485000.,  225000.,  285000.,  995000., 1475000.,  725000.,
#        4550000.,  495000.,  345000.,  320000.,  465000.,  340000.,
#         595000.,  250000.,  975000., 1100000.,  750000.,  439000.,
#         445000.,  915000., 1025000.,  265000.,  295000., 1175000.,
#         360000., 1050000.,  799000., 1700000.,  825000.,  290000.,
#         625000.,  859000.,  399500.,  430000., 1300000., 1750000.,
# ...

# %%
nit.groupby(['Area']).sum().plot(kind='pie', y='Room', title='I love you samina', colors=['red', 'yellow'], autopct='%1.0f%%')

# %%
fig= px.histogram(nit, x='Lat' ,width= 900,height=500, template='simple_white', color='Room', color_discrete_sequence=['purple','pink'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(nit, x='Lat' ,width= 900,height=500, template='plotly_dark', color='Room', color_discrete_sequence=['red','yellow'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(nit, x='Room' ,width= 900,height=500, template='simple_white', color='Area')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.set(style="darkgrid")
sns.displot(data=nit, x='Lon', bins=13, alpha=0.4, palette="Dark2");
sns.displot(data=nit, x='Lat', bins=13, alpha=0.4)

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %%
sns.violinplot(x= 'Lon', y='Lat', data= nit, color='r')

# %%
sns.violinplot(x= 'Room', data= nit, color='yellow')

# %%
sns.violinplot(x= 'Lon', data= nit, color='red')

# %%
sns.violinplot(x= 'Lat', data= nit, color='green')

# %%
sns.violinplot(x= 'Price', data= nit, color='cyan')

# %%
sns.violinplot(x= 'Area', data= nit, color='k')

# %%
plt.scatter(nit['Address'] , nit['Area'], color='g')
plt.colorbar()
plt.show()

# %%
plt.scatter(nit['Lon'] , nit['Lat'], color='c')
plt.colorbar()
plt.show()

# %%
plt.scatter(nit['Room'] , nit['Price'], color='m')
plt.colorbar()
plt.show()
